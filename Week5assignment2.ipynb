# %% [markdown]
# Q1-Explain why we have to use the Exception class while creating a Custom Exception.

# %% [raw]
# Ans-When creating a custom exception in Python, it is recommended to inherit from the built-in Exception class or one of its subclasses. Here's why:
#
# Consistency: Inheriting from the Exception class ensures that your custom exception follows the standard exception hierarchy in Python. This makes it easier for other developers to understand and work with your code because they are familiar with the existing exception classes and their behavior.
#
# Exception Handling: By inheriting from Exception, your custom exception can be caught and handled in a general except block that handles all types of exceptions. This allows you to handle your custom exception along with other built-in exceptions in a unified way.
#
# Exception Properties and Methods: The Exception class provides several useful properties and methods that you can leverage in your custom exception. For example, the message property allows you to store a custom error message, and methods like __str__ or __repr__ help in generating a string representation of the exception when it needs to be displayed or logged.
#
# Compatibility: Inheriting from Exception ensures that your custom exception is compatible with existing exception-related functionality and libraries in Python. For instance, if you're working with third-party libraries that catch and handle exceptions, they are more likely to handle your custom exception properly if it is derived from Exception.
#
# By inheriting from the Exception class, you ensure that your custom exception adheres to the established conventions and behaviors of exceptions in Python. This promotes code clarity, maintainability, and compatibility with the broader Python ecosystem.Ans-

# %% [markdown]
# Q2-Write a python program to print Python Exception Hierarchy.

# %%
def print_exception_hierarchy(exception_class, indent=0):
    print("  " * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 1)

print_exception_hierarchy(BaseException)
# Out:
# BaseException
#   Exception
#     TypeError
#       FloatOperation
#       MultipartConversionError
#     StopAsyncIteration
#     StopIteration
#     ImportError
#       ModuleNotFoundError
#       ZipImportError
#     OSError
#       ConnectionError
#         BrokenPipeError
#         ConnectionAbortedError
#         ConnectionRefusedError
#         ConnectionResetError
#           RemoteDisconnected
#       BlockingIOError
#       ChildProcessError
#       FileExistsError
#       FileNotFoundError
#       IsADirectoryError
#       NotADirectoryError
#       InterruptedError
#         InterruptedSystemCall
#       PermissionError
#       ProcessLookupError
#       TimeoutError
#       UnsupportedOperation
#       itimer_error
#       herror
#       gaierror
#       SSLError
#         SSLCertVerificationError
#         SSLZeroReturnError
#         SSLWantWriteError
#         SSLWantReadError
#         SSLSyscallError
#         SSLEOFError
#       Error
#         SameFileError
# ...

# %% [markdown]
# Q3-What errors are defined in the AirthmeticError class ? Explain any with an example.

# %% [markdown]
# Ans-The ArithmeticError class is a base class for arithmetic-related exceptions in Python. It serves as a parent class for several specific arithmetic exceptions, including:
#
# FloatingPointError: This exception is raised when a floating-point calculation encounters an error, such as an invalid operation or an overflow.
#
# OverflowError: This exception occurs when the result of an arithmetic operation exceeds the maximum representable value for a numeric type.
#
# ZeroDivisionError: This exception is raised when a division or modulo operation is performed with a divisor of zero

# %%
def divide_numbers(a, b):
    try:
        result = a / b
        print("Result:", result)
    except ZeroDivisionError:
        print("Error: Cannot divide by zero!")

num1 = 10
num2 = 0

divide_numbers(num1, num2)
# Out:
# Error: Cannot divide by zero!

# %% [markdown]
# Q4- Why LookupError class is used ? Explain with an example KeyError and IndexError.

# %% [markdown]
# Ans-The LookupError class is a base class for exceptions related to lookup or indexing operations. It serves as a parent class for specific lookup-related exceptions in Python, such as KeyError and IndexError. The purpose of LookupError is to handle situations where a lookup or indexing operation fails due to an invalid key or index.
#
# Let's look at KeyError and IndexError as examples:
#
# KeyError: This exception is raised when a dictionary key is not found. It occurs when you try to access a dictionary element using a key that does not exist in the dictionary.

# %%
dictionary = {"name": "John", "age": 25}

try:
    value = dictionary["address"]
except KeyError:
    print("Error: Key not found in the dictionary.")
# Out:
# Error: Key not found in the dictionary.

# %% [markdown]
# IndexError: This exception is raised when an index is out of range. It occurs when you try to access an element from a sequence (such as a list or a string) using an index that is beyond the valid range of indices for that sequence.

# %%
my_list = [1, 2, 3]

try:
    value = my_list[5]
except IndexError:
    print("Error: Index is out of range.")
# Out:
# Error: Index is out of range.

# %% [markdown]
# Q5-Explain ImportError . What is ModuleNotFoundError?

# %% [markdown]
# Ans-
# ImportError is an exception class in Python that is raised when an import statement fails to import a module or when there is an error related to module imports. It is a generic exception that encompasses various import-related errors.
#
# ModuleNotFoundError is a subclass of ImportError that specifically indicates that the requested module could not be found or imported. It was introduced in Python 3.6 to provide more specific information about import failures.

# %% [markdown]
# Q6-List down some best practices for exception handaling in python.
